# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from shutil import copy2
import csv

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # The %tensorflow_version magic only works in colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf

import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install tensorflow_hub
# Out:
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.6/dist-packages (0.11.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub) (3.12.4)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub) (1.19.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow_hub) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow_hub) (51.3.3)

# %%
import tensorflow_hub as hub

# %%
tf.__version__
# Out:
# '2.4.0'

# %%
import pandas as pd

# Increase precision of presented data for better side-by-side comparison
pd.set_option("display.precision", 8)

# %%
data_root = ("/content/drive/MyDrive/PokerImages/Dataset")

# %%
IMAGE_SHAPE = (224, 224)
TRAINING_DATA_DIR = str(data_root)

datagen_kwargs = dict(rescale=1./255, validation_split=.20)
valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(**datagen_kwargs)
valid_generator = valid_datagen.flow_from_directory(
    TRAINING_DATA_DIR, 
    subset="validation", 
    shuffle=True,
    target_size=IMAGE_SHAPE
)

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(**datagen_kwargs)
train_generator = train_datagen.flow_from_directory(
    TRAINING_DATA_DIR, 
    subset="training", 
    shuffle=True,
    target_size=IMAGE_SHAPE)
# Out:
# Found 49 images belonging to 5 classes.
# Found 202 images belonging to 5 classes.

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 224, 224, 3), (32, 5))

# %%
print (train_generator.class_indices)

labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('labels.txt', 'w') as f:
  f.write(labels)
# Out:
# {'Black': 0, 'Blue': 1, 'Green': 2, 'Red': 3, 'White': 4}

# %%
# !cat labels.txt
# Out:
# Black
# Blue
# Green
# Red
# White

# %%
IMAGE_SIZE = 224

# %%
model = tf.keras.Sequential([
  hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4", 
                 output_shape=[1280],
                 trainable=False),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(train_generator.num_classes, activation='softmax')
])
model.build([None, 224, 224, 3])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 6405
# =================================================================
# Total params: 2,264,389
# Trainable params: 6,405
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(lr=1e-3)

# %%
model.compile(
  optimizer=optimizer,
  loss='categorical_crossentropy',
  metrics=['acc'])

# %%
steps_per_epoch = np.ceil(train_generator.samples/train_generator.batch_size)
val_steps_per_epoch = np.ceil(valid_generator.samples/valid_generator.batch_size)

hist = model.fit(
    train_generator, 
    epochs=100,
    verbose=1,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=val_steps_per_epoch).history
# Out:
# Epoch 1/100
# 7/7 [==============================] - 81s 13s/step - loss: 1.5280 - acc: 0.3416 - val_loss: 1.1815 - val_acc: 0.4694
# Epoch 2/100
# 7/7 [==============================] - 39s 6s/step - loss: 1.1874 - acc: 0.5347 - val_loss: 0.9643 - val_acc: 0.6939
# Epoch 3/100
# 7/7 [==============================] - 40s 6s/step - loss: 0.9668 - acc: 0.6287 - val_loss: 0.8384 - val_acc: 0.7551
# Epoch 4/100
# 7/7 [==============================] - 39s 6s/step - loss: 0
100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0935 - acc: 0.9802 - val_loss: 0.2959 - val_acc: 0.9184
# Epoch 34/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0884 - acc: 0.9802 - val_loss: 0.2784 - val_acc: 0.9184
# Epoch 35/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0819 - acc: 0.9950 - val_loss: 0.2765 - val_acc: 0.9184
# Epoch 36/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0764 - acc: 0.9950 - val_loss: 0.2713 - val_acc: 0.9184
# Epoch 37/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0774 - acc: 0.9752 - val_loss: 0.2746 - val_acc: 0.9184
# Epoch 38/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0751 - acc: 0.9901 - val_loss: 0.2861 - val_acc: 0.9184
# Epoch 39/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0805 - acc: 0.9851 - val_loss: 0.2518 - val_acc: 0.9184
# Epoch 40/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0646 - acc: 0.9901 - val_loss: 0.2492 - val_acc: 0.9184
# Epoch 41/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0708 - acc: 0.9901 - val_loss: 0.2650 - val_acc: 0.9184
# Epoch 42/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0663 - acc: 0.9901 - val_loss: 0.2779 - val_acc: 0.9184
# Epoch 43/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0624 - acc: 0.9901 - val_loss: 0.2741 - val_acc: 0.9184
# Epoch 44/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0657 - acc: 0.9851 - val_loss: 0.2877 - val_acc: 0.9184
# Epoch 45/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0581 - acc: 0.9950 - val_loss: 0.2948 - val_acc: 0.9184
# Epoch 46/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0526 - acc: 0.9950 - val_loss: 0.2706 - val_acc: 0.9184
# Epoch 47/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0687 - acc: 0.9901 - val_loss: 0.2485 - val_acc: 0.9184
# Epoch 48/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0566 - acc: 0.9851 - val_loss: 0.2547 - val_acc: 0.9184
# Epoch 49/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0508 - acc: 0.9950 - val_loss: 0.2422 - val_acc: 0.9184
# Epoch 50/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0465 - acc: 1.0000 - val_loss: 0.2386 - val_acc: 0.9184
# Epoch 51/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0494 - acc: 0.9901 - val_loss: 0.2271 - val_acc: 0.9184
# Epoch 52/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0414 - acc: 1.0000 - val_loss: 0.2336 - val_acc: 0.9184
# Epoch 53/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0444 - acc: 0.9901 - val_loss: 0.2279 - val_acc: 0.9184
# Epoch 54/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0587 - acc: 0.9851 - val_loss: 0.2093 - val_acc: 0.9184
# Epoch 55/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0467 - acc: 1.0000 - val_loss: 0.2365 - val_acc: 0.9184
# Epoch 56/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0366 - acc: 1.0000 - val_loss: 0.2528 - val_acc: 0.9184
# Epoch 57/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0480 - acc: 1.0000 - val_loss: 0.2293 - val_acc: 0.9184
# Epoch 58/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0467 - acc: 1.0000 - val_loss: 0.2111 - val_acc: 0.9184
# Epoch 59/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0480 - acc: 0.9901 - val_loss: 0.2085 - val_acc: 0.9184
# Epoch 60/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0334 - acc: 1.0000 - val_loss: 0.2279 - val_acc: 0.9184
# Epoch 61/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0327 - acc: 1.0000 - val_loss: 0.2392 - val_acc: 0.9184
# Epoch 62/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0351 - acc: 1.0000 - val_loss: 0.2408 - val_acc: 0.9184
# Epoch 63/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0407 - acc: 1.0000 - val_loss: 0.2324 - val_acc: 0.9184
# Epoch 64/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0399 - acc: 1.0000 - val_loss: 0.2140 - val_acc: 0.9184
# Epoch 65/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0333 - acc: 1.0000 - val_loss: 0.1991 - val_acc: 0.9388
# Epoch 66/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0311 - acc: 1.0000 - val_loss: 0.2015 - val_acc: 0.9388
# Epoch 67/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0291 - acc: 1.0000 - val_loss: 0.2268 - val_acc: 0.9184
# Epoch 68/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0368 - acc: 0.9950 - val_loss: 0.2291 - val_acc: 0.9184
# Epoch 69/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0389 - acc: 0.9950 - val_loss: 0.2320 - val_acc: 0.9184
# Epoch 70/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0335 - acc: 0.9950 - val_loss: 0.2290 - val_acc: 0.9184
# Epoch 71/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0367 - acc: 1.0000 - val_loss: 0.2222 - val_acc: 0.9184
# Epoch 72/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0292 - acc: 1.0000 - val_loss: 0.2099 - val_acc: 0.9184
# Epoch 73/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0281 - acc: 1.0000 - val_loss: 0.1888 - val_acc: 0.9388
# Epoch 74/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0389 - acc: 0.9950 - val_loss: 0.1920 - val_acc: 0.9184
# Epoch 75/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0281 - acc: 1.0000 - val_loss: 0.2056 - val_acc: 0.9184
# Epoch 76/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0247 - acc: 0.9950 - val_loss: 0.2267 - val_acc: 0.9184
# Epoch 77/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0303 - acc: 1.0000 - val_loss: 0.2382 - val_acc: 0.9184
# Epoch 78/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0256 - acc: 1.0000 - val_loss: 0.2263 - val_acc: 0.9184
# Epoch 79/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0270 - acc: 1.0000 - val_loss: 0.2489 - val_acc: 0.9184
# Epoch 80/100
# 7/7 [==============================] - 40s 6s/step - loss: 0.0279 - acc: 1.0000 - val_loss: 0.2689 - val_acc: 0.9184
# Epoch 81/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0311 - acc: 0.9950 - val_loss: 0.2537 - val_acc: 0.9184
# Epoch 82/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0199 - acc: 1.0000 - val_loss: 0.2322 - val_acc: 0.9184
# Epoch 83/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0222 - acc: 1.0000 - val_loss: 0.2249 - val_acc: 0.9184
# Epoch 84/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0280 - acc: 1.0000 - val_loss: 0.2259 - val_acc: 0.9184
# Epoch 85/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0295 - acc: 0.9950 - val_loss: 0.2466 - val_acc: 0.9184
# Epoch 86/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0264 - acc: 1.0000 - val_loss: 0.2735 - val_acc: 0.9184
# Epoch 87/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0268 - acc: 1.0000 - val_loss: 0.2814 - val_acc: 0.8980
# Epoch 88/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0325 - acc: 1.0000 - val_loss: 0.2543 - val_acc: 0.9184
# Epoch 89/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0309 - acc: 0.9950 - val_loss: 0.2088 - val_acc: 0.9184
# Epoch 90/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0287 - acc: 0.9950 - val_loss: 0.1862 - val_acc: 0.9388
# Epoch 91/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0271 - acc: 0.9950 - val_loss: 0.2048 - val_acc: 0.9388
# Epoch 92/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0213 - acc: 1.0000 - val_loss: 0.2274 - val_acc: 0.9184
# Epoch 93/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0253 - acc: 1.0000 - val_loss: 0.2447 - val_acc: 0.9184
# Epoch 94/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0215 - acc: 1.0000 - val_loss: 0.2410 - val_acc: 0.9184
# Epoch 95/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0236 - acc: 1.0000 - val_loss: 0.2250 - val_acc: 0.9184
# Epoch 96/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0193 - acc: 1.0000 - val_loss: 0.2074 - val_acc: 0.9184
# Epoch 97/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0242 - acc: 1.0000 - val_loss: 0.2232 - val_acc: 0.9184
# Epoch 98/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0304 - acc: 0.9901 - val_loss: 0.2182 - val_acc: 0.9184
# Epoch 99/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0184 - acc: 1.0000 - val_loss: 0.1992 - val_acc: 0.9184
# Epoch 100/100
# 7/7 [==============================] - 39s 6s/step - loss: 0.0264 - acc: 0.9950 - val_loss: 0.2151 - val_acc: 0.9184

# %%
final_loss, final_accuracy = model.evaluate(valid_generator, steps = val_steps_per_epoch)
print("Final loss: {:.2f}".format(final_loss))
print("Final accuracy: {:.2f}%".format(final_accuracy * 100))
# Out:
# 2/2 [==============================] - 8s 3s/step - loss: 0.2151 - acc: 0.9184
# Final loss: 0.22
# Final accuracy: 91.84%

# %%
plt.figure()
plt.ylabel("Loss (training and validation)")
plt.xlabel("Training Steps")
plt.ylim([0,50])
plt.plot(hist["loss"])
plt.plot(hist["val_loss"])

plt.figure()
plt.ylabel("Accuracy (training and validation)")
plt.xlabel("Training Steps")
plt.ylim([0,1])
plt.plot(hist["acc"])
plt.plot(hist["val_acc"])

# %%
val_image_batch, val_label_batch = next(iter(valid_generator))
true_label_ids = np.argmax(val_label_batch, axis=-1)
print("Validation batch shape:", val_image_batch.shape)
# Out:
# Validation batch shape: (32, 224, 224, 3)

# %%
dataset_labels = sorted(train_generator.class_indices.items(), key=lambda pair:pair[1])
dataset_labels = np.array([key.title() for key, value in dataset_labels])
print(dataset_labels)
# Out:
# ['Black' 'Blue' 'Green' 'Red' 'White']

# %%
tf_model_predictions = model.predict(val_image_batch)
print("Prediction results shape:", tf_model_predictions.shape)
# Out:
# Prediction results shape: (32, 5)

# %%
predicted_ids = np.argmax(tf_model_predictions, axis=-1)
predicted_labels = dataset_labels[predicted_ids]
print(predicted_labels)
# Out:
# ['Black' 'Black' 'Red' 'Green' 'White' 'Black' 'White' 'Black' 'Red'
#  'White' 'Green' 'Green' 'White' 'Blue' 'Red' 'Green' 'Blue' 'Red' 'Blue'
#  'Red' 'Blue' 'Green' 'White' 'Green' 'Green' 'Black' 'Green' 'Green'
#  'Blue' 'Red' 'Black' 'Black']

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range((len(predicted_labels)-2)):
  plt.subplot(6,5,n+1)
  plt.imshow(val_image_batch[n])
  color = "green" if predicted_ids[n] == true_label_ids[n] else "red"
  plt.title(predicted_labels[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (green: correct, red: incorrect)")
